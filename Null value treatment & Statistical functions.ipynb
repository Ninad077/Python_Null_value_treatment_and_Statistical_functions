# %% [markdown]
# # Null value treatment & Statistical functions

# %%
import pandas as pd

# %% [markdown]
# Reading a csv file using pandas in python

# %%
data = pd.read_csv("Salaries.csv")

# %%
data
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %% [markdown]
# Reading an excel file using pandas in python

# %%
data = pd.read_excel("mtcars.xlsx")

# %%
data
# Out:
#     mpg  Unnamed: 1   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0    21         NaN  160.0  110  3.90  2.620  16.46   0   0     4     4
# 1    21         NaN  160.0  110  3.90  2.875  17.02   0   0     4     4
# 2    22         8.0  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3    21         4.0  258.0  110  3.08  3.215  19.44   1   1     3     1
# 4    18         7.0  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5    18         1.0  225.0  105  2.76  3.460  20.22   1   1     3     1
# 6    14         3.0  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7    24         4.0  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8    22         8.0  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9    19         2.0  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10   17         8.0  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11   16         4.0  275.8  180  3.07  4.070  17.40   0   0     3     3
# ...

# %% [markdown]
# Reading an excel file using pandas in python and speciying index, header & encoding

# %%
# Pandas as a library tends to create an index column by default while reading a file.
# By specifying index_col =0 we are specifying the pandas to use 0th column (i.e Sr no.) as the index column
# By specifying header =0 we are specifying the pandas to use the default header if we use header = None, it will demote the header
# By specifying encoding="utf-8" we are specifying the pandas to eliminate any error in case of special characters.

data = pd.read_excel("mtcars.xlsx",index_col=0,header=0)

# %%
data
# Out:
#      Unnamed: 1   disp   hp  drat     wt   qsec  vs  am  gear  carb
# mpg
# 21          NaN  160.0  110  3.90  2.620  16.46   0   0     4     4
# 21          NaN  160.0  110  3.90  2.875  17.02   0   0     4     4
# 22          8.0  108.0   93  3.85  2.320  18.61   1   1     4     1
# 21          4.0  258.0  110  3.08  3.215  19.44   1   1     3     1
# 18          7.0  360.0  175  3.15  3.440  17.02   0   0     3     2
# 18          1.0  225.0  105  2.76  3.460  20.22   1   1     3     1
# 14          3.0  360.0  245  3.21  3.570  15.84   0   0     3     4
# 24          4.0  146.7   62  3.69  3.190  20.00   1   0     4     2
# 22          8.0  140.8   95  3.92  3.150  22.90   1   0     4     2
# 19          2.0  167.6  123  3.92  3.440  18.30   1   0     4     4
# 17          8.0  167.6  123  3.92  3.440  18.90   1   0     4     4
# 16          4.0  275.8  180  3.07  4.070  17.40   0   0     3     3
# 17          3.0  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %% [markdown]
# Describing the dataset

# %%
data.describe()      # Gives statistical desrciption of data (For e.g. Mean,Median, Mode...)
# Out:
#        Unnamed: 1        disp          hp       drat         wt       qsec  \
# count   28.000000   32.000000   32.000000  32.000000  32.000000  32.000000
# mean     4.607143  230.721875  146.687500   3.596563   3.217250  17.848750
# std      2.249927  123.938694   68.562868   0.534679   0.978457   1.786943
# min      1.000000   71.100000   52.000000   2.760000   1.513000  14.500000
# 25%      3.000000  120.825000   96.500000   3.080000   2.581250  16.892500
# 50%      4.000000  196.300000  123.000000   3.695000   3.325000  17.710000
# 75%      7.000000  326.000000  180.000000   3.920000   3.610000  18.900000
# max      9.000000  472.000000  335.000000   4.930000   5.424000  22.900000
#
#               vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.0000
# mean    0.437500   0.406250   3.687500   2.8125
# std     0.504016   0.498991   0.737804   1.6152
# min     0.000000   0.000000   3.000000   1.0000
# 25%     0.000000   0.000000   3.000000   2.0000
# ...

# %% [markdown]
# Information about the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, 21 to 21
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 1  28 non-null     float64
#  1   disp        32 non-null     float64
#  2   hp          32 non-null     int64
#  3   drat        32 non-null     float64
#  4   wt          32 non-null     float64
#  5   qsec        32 non-null     float64
#  6   vs          32 non-null     int64
#  7   am          32 non-null     int64
#  8   gear        32 non-null     int64
#  9   carb        32 non-null     int64
# dtypes: float64(5), int64(5)
# memory usage: 2.8 KB

# %% [markdown]
# Fetching the column headers

# %%
data.columns
# Out:
# Index(['Unnamed: 1', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %% [markdown]
# Fetching the size of dataset

# %%
data.shape
# Out:
# (32, 10)

# %% [markdown]
# Describing the type of the column header

# %%
data.dtypes
# Out:
# Unnamed: 1    float64
# disp          float64
# hp              int64
# drat          float64
# wt            float64
# qsec          float64
# vs              int64
# am              int64
# gear            int64
# carb            int64
# dtype: object

# %% [markdown]
# Task: Make multiple lists segregating dtypes of the column headers

# %%
data =pd.read_csv("Salaries.csv")

# %%
data
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
object_list=[]
int_list=[]
for i in data.columns:
    if data[i].dtype == "int64":
        int_list.append(i)
    else:
        object_list.append(i)

# %%
int_list
# Out:
# ['phd', 'service', 'salary']

# %%
object_list
# Out:
# ['rank', 'discipline', 'sex']

# %% [markdown]
# Fetching the top number of rows in a table

# %%
data.head(5)
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %% [markdown]
# Fetching the bottom number of rows from a table

# %%
data.tail(2)
# Out:
#     rank discipline  phd  service     sex  salary
# 76  Prof          A   28       14  Female  109954
# 77  Prof          A   23       15  Female  109646

# %% [markdown]
# Fetching a column

# %%
data["phd"]

# %% [markdown]
# Statistics: Mean, Median & Mode

# %%
# Mean: Retruns the average value of the column

data["phd"].mean()
# Out:
# 19.705128205128204

# %%
# Median : Returns the central value from the dataset

data["phd"].median()
# Out:
# 18.5

# %%
# Mode : Returns the repeated value (highly frequent value) from the dataset

data["phd"].mode()
# Out:
# 0    4
# Name: phd, dtype: int64

# %%
# Specifying the index of the mode we want. 
# Say in the above case we got 2 values 0 and 4. If we want 0 write index as [0] or if want 4 write index as [1]

data["phd"].mode()[0]
# Out:
# 4

# %% [markdown]
# Null value treatment

# %%
# The most important thing in Data preprocessing is to treat the null values before implementing the data on Machine 
# Learning algorithms. Because one can't apply data with missing values on Machine Learning algorithms.
# To show an example for the same we have removed some data from the "Salaries.csv" file and updated it to 
# "Salaries_new.csv". So this new file now has null entries as well.

data_new= pd.read_excel("Salaries_new.xlsx")

# %%
data_new
# Out:
#          rank discipline   phd  service     sex  salary
# 0        Prof          B  56.0     49.0    Male  186960
# 1        Prof          A  12.0      6.0    Male   93000
# 2        Prof          A  23.0     20.0    Male  110515
# 3        Prof          A  40.0     31.0    Male  131205
# 4        Prof          B  20.0     18.0    Male  104800
# ..        ...        ...   ...      ...     ...     ...
# 73       Prof          B  18.0     10.0  Female  105450
# 74  AssocProf          B  19.0      6.0  Female  104542
# 75       Prof          B  17.0     17.0  Female  124312
# 76       Prof          A  28.0     14.0  Female  109954
# 77       Prof          A  23.0     15.0  Female  109646
#
# [78 rows x 6 columns]

# %%
# isnull()
# isnull() function substitutes 'True' in the place where we've null values and 'False' in the place of non-null values

data_new.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
# isnull().sum()
# isnull().sum() returns the total number of null values in a particular column

data_new.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           6
# service       3
# sex           0
# salary        0
# dtype: int64

# %%
# fillna()
# fillna() is used to fill the null values with the value specified inside it's argument.

# Looking at the o/p above we have got null values for the column phd and service. Let us try to replace the null values 
# the phd column with it's mean. The query would look like

data_new["phd"].fillna(data_new["phd"].mean())
# Out:
# 0     56.0
# 1     12.0
# 2     23.0
# 3     40.0
# 4     20.0
#       ...
# 73    18.0
# 74    19.0
# 75    17.0
# 76    28.0
# 77    23.0
# Name: phd, Length: 78, dtype: float64

# %%
# Now adding an extra argument inplace = True, so inplace will substitute the null values with the specified value 
# (i.e. mean in this example) not only in phd column, but also in the original dataset. 
# So if we fetch the original datset back, the eliminated null values would be reflected in the table.

data_new["phd"].fillna(data_new["phd"].mean(),inplace =True)

# %%
data_new
# Out:
#          rank discipline   phd  service     sex  salary
# 0        Prof          B  56.0     49.0    Male  186960
# 1        Prof          A  12.0      6.0    Male   93000
# 2        Prof          A  23.0     20.0    Male  110515
# 3        Prof          A  40.0     31.0    Male  131205
# 4        Prof          B  20.0     18.0    Male  104800
# ..        ...        ...   ...      ...     ...     ...
# 73       Prof          B  18.0     10.0  Female  105450
# 74  AssocProf          B  19.0      6.0  Female  104542
# 75       Prof          B  17.0     17.0  Female  124312
# 76       Prof          A  28.0     14.0  Female  109954
# 77       Prof          A  23.0     15.0  Female  109646
#
# [78 rows x 6 columns]

# %%
# Checking the null values for phd column now

data_new.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       3
# sex           0
# salary        0
# dtype: int64

# %%
# As one can clearly see, the null values of phd column are eliminated (since, sum of phd null values =0)

# %%
# Similary treating the null values of service column by it's mode

data_new["service"].fillna(data_new["service"].mode()[0],inplace=True)

# %%
data_new.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %% [markdown]
# Unique value treatment

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("adult_new.csv")

# %%
df
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 0       28         Local-gov  336951    Assoc-acdm               12
# 1       44           Private  160323  Some-college               10
# 2       63  Self-emp-not-inc  104626   Prof-school               15
# 3       65           Private  184454       HS-grad                9
# 4       48           Private  279724       HS-grad                9
# ...    ...               ...     ...           ...              ...
# 27409   27           Private  257302    Assoc-acdm               12
# 27410   40           Private  154374       HS-grad                9
# 27411   58           Private  151910       HS-grad                9
# 27412   22           Private  201490       HS-grad                9
# 27413   52      Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0      Married-civ-spouse    Protective-serv      Husband  White    Male
# ...

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
# At times, even if we see zero null values in the data, we do have some redundant values. 
# This can be checked by using unique function.
# Let us check unique values for the coulmn "workcalss"

df["workclass"].unique()
# Out:
# array(['Local-gov', 'Private', 'Self-emp-not-inc', 'State-gov',
#        'Self-emp-inc', '?', 'Federal-gov', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
# Now let us check unique values for every column in the data df

for i in df.columns:
    print(f"Unique value for coulmn: {i}\n\n{df[i].unique()}\n")   ## f string is used to make data dynamic
# Out:
# Unique value for coulmn: age
#
# [28 44 63 65 48 43 40 34 45 46 36 22 42 41 55 33 59 29 27 31 58 54 37 56
#  39 51 50 52 47 24 64 53 35 32 30 68 57 66 49 38 61 73 26 23 25 62 90 60
#  67 69 72 85 71 77 70 19 21 74 75 20 81 76 80 88 78 79 84 17 18 82 83 86
#  87]
#
# Unique value for coulmn: workclass
#
# ['Local-gov' 'Private' 'Self-emp-not-inc' 'State-gov' 'Self-emp-inc' '?'
#  'Federal-gov' 'Without-pay' 'Never-worked']
#
# Unique value for coulmn: fnlwgt
#
# [336951 160323 104626 ...  84661 310152 257302]
#
# Unique value for coulmn: education
#
# ['Assoc-acdm' 'Some-college' 'Prof-school' 'HS-grad' 'Masters' 'Doctorate'
#  'Bachelors' 'Assoc-voc' '9th' '10th' '7th-8th' '11th' '5th-6th' '1st-4th'
#  '12th' 'Preschool']
#
# Unique value for coulmn: educational-num
#
# [12 10 15  9 14 16 13 11  5  6  4  7  3  2  8  1]
#
# Unique value for coulmn: marital-status
#
# ['Married-civ-spouse' 'Never-married' 'Divorced' 'Separated'
#  'Married-AF-spouse' 'Widowed' 'Married-spouse-absent']
# ...

# %%
# As one can see from the output above, null values can also be present in the form of "?" in the dataset.
# Generally such null values, are left unidentified using isnull fn.
# To identify such null values, we use unique() fn & replace() fn

df.replace("?",np.nan, inplace= True) ## Here we're intentionally replacing the ? mark with null values, so that
                                      ## it gets identified when we use isnull fn

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          1283
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         1288
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      508
# income                0
# dtype: int64

# %%
#Task: Write a code treating null values with mode if the column is categorical (dtype: object)
# and treating null values with mean if the column is numeric (dtype: int64 ordtype: int64 ) for the source "data_new"

data_new= pd.read_excel("Salaries_new.xlsx")

# %%
data_new
# Out:
#          rank discipline   phd  service     sex  salary
# 0        Prof          B  56.0     49.0    Male  186960
# 1        Prof          A  12.0      6.0    Male   93000
# 2        Prof          A  23.0     20.0    Male  110515
# 3        Prof          A  40.0     31.0    Male  131205
# 4        Prof          B  20.0     18.0    Male  104800
# ..        ...        ...   ...      ...     ...     ...
# 73       Prof          B  18.0     10.0  Female  105450
# 74  AssocProf          B  19.0      6.0  Female  104542
# 75       Prof          B  17.0     17.0  Female  124312
# 76       Prof          A  28.0     14.0  Female  109954
# 77       Prof          A  23.0     15.0  Female  109646
#
# [78 rows x 6 columns]

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         72 non-null     float64
#  3   service     75 non-null     float64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.8+ KB

# %%
data_new.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
def Null_Value_Treatment(data_new):
    for i in data_new.columns:
        if data_new[i].dtypes == "int64" or data_new[i].dtypes == "float64":
            data_new[i].fillna(data_new[i].mean(),inplace=True)
        else:
            data_new[i].fillna(data_new[i].mode()[0],inplace=True)
    return data_new.isnull().sum()

# %%
Null_Value_Treatment(data_new)
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
#Task: Write a code treating null values with mode if the column is categorical (dtype: object)
# and treating null values with mean if the column is numeric (dtype: int64 ordtype: int64 ) for the source "df"

df=pd.read_csv("adult_new.csv")

# %%
df
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 0       28         Local-gov  336951    Assoc-acdm               12
# 1       44           Private  160323  Some-college               10
# 2       63  Self-emp-not-inc  104626   Prof-school               15
# 3       65           Private  184454       HS-grad                9
# 4       48           Private  279724       HS-grad                9
# ...    ...               ...     ...           ...              ...
# 27409   27           Private  257302    Assoc-acdm               12
# 27410   40           Private  154374       HS-grad                9
# 27411   58           Private  151910       HS-grad                9
# 27412   22           Private  201490       HS-grad                9
# 27413   52      Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0      Married-civ-spouse    Protective-serv      Husband  White    Male
# ...

# %%
df.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
def Null_Value_Treatment(df):
    for i in df.columns:
        if df[i].dtypes == "int64" or df[i].dtypes == "float64":
            df[i].fillna(df[i].mean(),inplace=True)
        else:
            df[i].fillna(df[i].mode()[0],inplace=True)
    return df.isnull().sum()

# %%
Null_Value_Treatment(df)
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64
